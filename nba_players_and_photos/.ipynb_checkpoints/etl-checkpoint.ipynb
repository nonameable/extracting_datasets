# %%
import pandas as pd

# %%
file_path = './players_stats.csv'
players = pd.read_csv(file_path)

# %%
players.head(10)
# Out:
#             Name  Games Played   MIN   PTS  FGM   FGA   FG%  3PM  3PA   3P%  \
# 0       AJ Price            26   324   133   51   137  37.2   15   57  26.3
# 1   Aaron Brooks            82  1885   954  344   817  42.1  121  313  38.7
# 2   Aaron Gordon            47   797   243   93   208  44.7   13   48  27.1
# 3  Adreian Payne            32   740   213   91   220  41.4    1    9  11.1
# 4     Al Horford            76  2318  1156  519   965  53.8   11   36  30.6
# 5   Al Jefferson            65  1992  1082  486  1010  48.1    2    5  40.0
# 6  Alan Anderson            74  1744   545  195   440  44.3   73  210  34.8
# 7     Alec Burks            27   899   374  121   300  40.3   26   68  38.2
# 8      Alex Kirk             5    14     4    1     4  25.0    0    0   0.0
# 9       Alex Len            69  1518   432  179   353  50.7    1    3  33.3
#
#      ...       Age  Birth_Place           Birthdate  \
# 0    ...      29.0           us     October 7, 1986
# ...

# %%
list(players)
# Out:
# ['Name',
#  'Games Played',
#  'MIN',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FG%',
#  '3PM',
#  '3PA',
#  '3P%',
#  'FTM',
#  'FTA',
#  'FT%',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'EFF',
#  'AST/TOV',
#  'STL/TOV',
#  'Age',
#  'Birth_Place',
#  'Birthdate',
#  'Collage',
#  'Experience',
#  'Height',
#  'Pos',
#  'Team',
#  'Weight',
#  'BMI']

# %%
# lets select some columns
cols_to_select = ['Name', 'Games Played', 'MIN', 'PTS', '3P%', 'FT%', 'OREB', 'DREB', 'AST', 'STL', 'BLK','Age',
 'Birth_Place',
 'Birthdate',
 'Collage',
 'Experience',
 'Height',
 'Pos',
 'Team',
 'Weight',
 'BMI' ]

# %%
cols_to_select
# Out:
# ['Name',
#  'Games Played',
#  'MIN',
#  'PTS',
#  '3P%',
#  'FT%',
#  'OREB',
#  'DREB',
#  'AST',
#  'STL',
#  'BLK',
#  'Age',
#  'Birth_Place',
#  'Birthdate',
#  'Collage',
#  'Experience',
#  'Height',
#  'Pos',
#  'Team',
#  'Weight',
#  'BMI']

# %%
players_selection = players[cols_to_select]

# %%
players_selection.head()
# Out:
#             Name  Games Played   MIN   PTS   3P%   FT%  OREB  DREB  AST  STL  \
# 0       AJ Price            26   324   133  26.3  66.7     6    26   46    7
# 1   Aaron Brooks            82  1885   954  38.7  83.3    32   134  261   54
# 2   Aaron Gordon            47   797   243  27.1  72.1    46   123   33   21
# 3  Adreian Payne            32   740   213  11.1  65.2    48   114   30   19
# 4     Al Horford            76  2318  1156  30.6  75.9   131   413  244   68
#
#      ...       Age  Birth_Place           Birthdate  \
# 0    ...      29.0           us     October 7, 1986
# 1    ...      30.0           us    January 14, 1985
# 2    ...      20.0           us  September 16, 1995
# 3    ...      24.0           us   February 19, 1991
# 4    ...      29.0           do        June 3, 1986
#
#                      Collage Experience Height  Pos Team  Weight        BMI
# 0  University of Connecticut          5  185.0   PG  PHO   81.45  23.798393
# ...

# %%
names = list(players_selection['Name'])

# %%
with open("players.txt", "w") as f: 
    for name in names:
        f.write(name + "\n")

# %%
# we obtain the photos and save them in the players folder
from google_images_download import google_images_download
response = google_images_download.googleimagesdownload()
arguments = {"keywords_from_file":"./players.txt","limit":1,"print_urls":True,
             "format":"png", "no_directory":False, "output_directory": "players", "no_numbering":True}
#paths = response.download(arguments)   #uncomment this to download the photos
#print(paths)
# Out:
# Item no.: 1 --> Item name = AJ Price
# Evaluating...
# Starting Download...
# Image URL: http://a.espncdn.com/combiner/i?img=/i/headshots/nba/players/full/4010.png&w=350&h=254
# Completed Image ====> 1. 4010.png&w=350&h=254.jpg
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = Aaron Brooks
# Evaluating...
# Starting Download...
# Image URL: http://a.espncdn.com/combiner/i?img=/i/headshots/nba/players/full/3192.png&w=350&h=254
# Completed Image ====> 1. 3192.png&w=350&h=254.jpg
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = Aaron Gordon
# Evaluating...
# Starting Download...
# Image URL: http://a.espncdn.com/combiner/i?img=/i/headshots/nba/players/full/3064290.png&w=350&h=254
# Completed Image ====> 1. 3064290.png&w=350&h=254.jpg
#
# Errors: 0
#
#
# Item no.: 4 --> Item name = Adreian Payne
# Evaluating...
# Starting Download...
# Image URL: http://a.espncdn.com/combiner/i?img=/i/headshots/nba/players/full/2531100.png&w=350&h=254
# Completed Image ====> 1. 2531100.png&w=350&h=254.jpg
# ...

# %%
# formatting images You can only run this cell once, after that, all the names will be lowercase
import os
for name in names:
    path = "./players/" + name + "/"
    file_name = next(os.walk(path))[2][0]
    new_file_name = name.lower().replace(" ", "-")
    # rename the png file
    os.rename(path + file_name, path + new_file_name + ".png")
    # rename the folder for an easier url
    os.rename("./players/" + name,"./players/" + new_file_name )

# %%
https://raw.githubusercontent.com/nonameable/extracting_datasets/nba_players_and_photos/players/

# %%
https://raw.githubusercontent.com/nonameable/visualizando-python/master/images/exercise_1-1.png

# %%
players_selection['url'] = players_selection['Team'] # throws warning, chill
# Out:
# /Users/damaderu/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
list(players_selection)
# Out:
# ['Name',
#  'Games Played',
#  'MIN',
#  'PTS',
#  '3P%',
#  'FT%',
#  'OREB',
#  'DREB',
#  'AST',
#  'STL',
#  'BLK',
#  'Age',
#  'Birth_Place',
#  'Birthdate',
#  'Collage',
#  'Experience',
#  'Height',
#  'Pos',
#  'Team',
#  'Weight',
#  'BMI',
#  'url']

# %%
players_selection.head()
# Out:
#             Name  Games Played   MIN   PTS   3P%   FT%  OREB  DREB  AST  STL  \
# 0       AJ Price            26   324   133  26.3  66.7     6    26   46    7
# 1   Aaron Brooks            82  1885   954  38.7  83.3    32   134  261   54
# 2   Aaron Gordon            47   797   243  27.1  72.1    46   123   33   21
# 3  Adreian Payne            32   740   213  11.1  65.2    48   114   30   19
# 4     Al Horford            76  2318  1156  30.6  75.9   131   413  244   68
#
#      ...       Age  Birth_Place           Birthdate  \
# 0    ...      29.0           us     October 7, 1986
# 1    ...      30.0           us    January 14, 1985
# 2    ...      20.0           us  September 16, 1995
# 3    ...      24.0           us   February 19, 1991
# 4    ...      29.0           do        June 3, 1986
#
#                      Collage Experience Height  Pos Team  Weight        BMI
# 0  University of Connecticut          5  185.0   PG  PHO   81.45  23.798393
# ...

# %%
basic_url = "https://raw.githubusercontent.com/nonameable/extracting_datasets/master/nba_players_and_photos/players"
for name in names:
    correct_name = name.lower().replace(" ", "-")
    url = basic_url + "/" + correct_name + "/" + correct_name + ".png" 
    players_selection.loc[players_selection['Name'] == name, 'url'] = url
# Out:
# /Users/damaderu/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
players_selection.loc[players_selection['Name'] == 'AJ Price', 'url'] = "https://raw.githubusercontent.com/nonameable/extracting_datasets/nba_players_and_photos/players/aj-price/aj-price.png"
# Out:
# /Users/damaderu/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
players_selection.loc[players_selection['Name'] == 'AJ Price']
# Out:
#        Name  Games Played  MIN  PTS   3P%   FT%  OREB  DREB  AST  STL  \
# 0  AJ Price            26  324  133  26.3  66.7     6    26   46    7
#
#                          ...                          Birth_Place  \
# 0                        ...                                   us
#
#          Birthdate                    Collage Experience Height Pos  Team  \
# 0  October 7, 1986  University of Connecticut          5  185.0  PG   PHO
#
#   Weight        BMI                                                url
# 0  81.45  23.798393  https://raw.githubusercontent.com/nonameable/e...
#
# [1 rows x 22 columns]

# %%
players_selection.head(1)['url']
# Out:
# 0    https://raw.githubusercontent.com/nonameable/e...
# Name: url, dtype: object

# %%
file_name = "nba_players.csv"
players_selection.to_csv(file_name, sep=',', encoding='utf-8')
